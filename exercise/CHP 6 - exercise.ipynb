# %% [markdown]
# ### Exercise 2

# %% [markdown]
# For binary classification, sample LDA classifier:
# ![image.png](attachment:image.png)
#
# Given $\mathbf{\hat{\mu}_{0}}$, $\mathbf{\hat{\mu}_{1}}$, $\mathbf{\hat{\Sigma}}$, $\mathbf{x}$. Plug in the values to determine the range of $P(Y=1)$ such that observation $\mathbf{x}$ is classified to class 1.

# %% [markdown]
# ### Exercise 3

# %% [markdown]
# For multiclass classification:
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# Given $\mathbf{\hat{\mu}_{0}}$, $\mathbf{\hat{\mu}_{1}}$, $\mathbf{\hat{\mu}_{2}}$, $\mathbf{\hat{\Sigma}}$, $\mathbf{x}$. Assume that classes are equiprobable. Plug in the values to determine the class.
